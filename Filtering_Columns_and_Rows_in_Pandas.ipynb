# %%
import pandas as pd
df = pd.read_excel("/content/E-Commerce Sales Analytics.xlsx")
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
import pandas as pd
df2 = pd.read_excel("/content/E-Commerce Sales Analytics.xlsx")
df2
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df[df['customer_id'] <= 1050]
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 7        10008 2022-01-08         1020           Beauty  North         6
# 34       10035 2022-02-04         1021      Electronics   West         2
# 61       10062 2022-03-03         1020         Clothing   East         7
# 68       10069 2022-03-10         1013             Home  North         4
# 83       10084 2022-03-25         1034         Clothing  North         1
# ...        ...        ...          ...              ...    ...       ...
# 4920     14921 2035-06-22         1018             Home  South         1
# 4932     14933 2035-07-04         1024             Home   West         7
# 4934     14935 2035-07-06         1000      Electronics   East         2
# 4971     14972 2035-08-12         1044      Electronics   West         5
# 4990     14991 2035-08-31         1012             Home   East         1
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
specific_category= ["Clothing", "Electronics"]
df[df['product_category'].isin(specific_category)]
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 1        10002 2022-01-02         1435         Clothing  South         7
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# 5        10006 2022-01-06         1071      Electronics   West         2
# 6        10007 2022-01-07         1700         Clothing  South         6
# ...        ...        ...          ...              ...    ...       ...
# 4988     14989 2035-08-29         1449         Clothing   West         1
# 4989     14990 2035-08-30         1473         Clothing   East         4
# 4993     14994 2035-09-03         1926      Electronics   West         1
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4998     14999 2035-09-08         1903      Electronics  South         4
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df[df['product_category'].str.contains("thing")]
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 1        10002 2022-01-02         1435         Clothing  South         7
# 4        10005 2022-01-05         1106         Clothing   West         5
# 6        10007 2022-01-07         1700         Clothing  South         6
# 8        10009 2022-01-09         1614         Clothing  South         6
# 9        10010 2022-01-10         1121         Clothing   West         4
# ...        ...        ...          ...              ...    ...       ...
# 4985     14986 2035-08-26         1357         Clothing   East         2
# 4986     14987 2035-08-27         1187         Clothing  North         6
# 4988     14989 2035-08-29         1449         Clothing   West         1
# 4989     14990 2035-08-30         1473         Clothing   East         4
# 4995     14996 2035-09-05         1289         Clothing   West         2
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df = df.set_index("region")
df
# Out:
#         order_id order_date  customer_id product_category  quantity  \
# region
# South      10001 2022-01-01         1102           Beauty         7
# South      10002 2022-01-02         1435         Clothing         7
# East       10003 2022-01-03         1860           Beauty         3
# West       10004 2022-01-04         1270      Electronics         5
# West       10005 2022-01-05         1106         Clothing         5
# ...          ...        ...          ...              ...       ...
# West       14996 2035-09-05         1289         Clothing         2
# North      14997 2035-09-06         1294           Beauty         3
# West       14998 2035-09-07         1450           Beauty         3
# South      14999 2035-09-08         1903      Electronics         4
# East       15000 2035-09-09         1214             Home         7
#
#         unit_price  discount payment_method  delivery_days  customer_rating  \
# region
# ...

# %%
df.filter(items =['product_category', 'payment_method'])
# Out:
#        product_category payment_method
# region
# South            Beauty         Wallet
# South          Clothing           Card
# East             Beauty            COD
# West        Electronics         Wallet
# West           Clothing         Wallet
# ...                 ...            ...
# West           Clothing            COD
# North            Beauty            COD
# West             Beauty         Wallet
# South       Electronics            COD
# East               Home            COD
#
# [5000 rows x 2 columns]

# %%
df2[df2['quantity'] <= 3].sort_values(by="quantity", ascending=False)
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 4967     14968 2035-08-08         1972             Home   East         3
# 44       10045 2022-02-14         1699             Home   East         3
# 36       10037 2022-02-06         1747         Clothing  South         3
# 18       10019 2022-01-19         1663             Home   West         3
# 16       10017 2022-01-17         1099         Clothing  North         3
# ...        ...        ...          ...              ...    ...       ...
# 43       10044 2022-02-13         1475      Electronics  North         1
# 38       10039 2022-02-08         1560      Electronics   East         1
# 33       10034 2022-02-03         1313             Home  North         1
# 23       10024 2022-01-24         1343         Clothing   East         1
# 20       10021 2022-01-21         1661             Home   West         1
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...
